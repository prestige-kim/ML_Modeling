# %%
import pandas as pd

ds = pd.read_csv('../../../data/week5_us_retail_sales_nsa.csv')

ds
# Out:
#     observation_date  MRTSSM44X72USN
# 0         1992-01-01          142051
# 1         1992-02-01          142498
# 2         1992-03-01          154439
# 3         1992-04-01          158430
# 4         1992-05-01          164788
# ..               ...             ...
# 408       2026-01-01          674374
# 409       2026-02-01          656082
# 410       2026-03-01          761135
# 411       2026-04-01          755742
# 412       2026-05-01          796039
#
# [413 rows x 2 columns]
