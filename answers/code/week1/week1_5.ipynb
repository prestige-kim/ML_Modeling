# %%
import pandas as pd
import matplotlib as plt

ds = pd.read_csv('/Users/proudchris/Desktop/ML_modeling/data/week1_macro_practice.csv')

# %%
ds.date = pd.to_datetime(ds.date)
ds = ds.sort_values('date', ascending=True)

# %%
ds.plot(x='date', y='industrial_production_index', kind='line', title='Industrial Production IDX')
# Out:
# <Axes: title={'center': 'Industrial Production IDX'}, xlabel='date'>

# %%
ds.plot(x='date', y='pmi', kind='line', title='PMI')
# Out:
# <Axes: title={'center': 'PMI'}, xlabel='date'>
