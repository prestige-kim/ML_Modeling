# %%
import pandas as pd

data_set = pd.read_csv("/Users/proudchris/Desktop/ML_modeling/data/week1_macro_practice.csv")
data_set.head()
# Out:
#          date  industrial_production_index   pmi  policy_rate  \
# 0  2021-01-31                         96.8  49.8          0.5
# 1  2021-02-28                         97.4  50.2          0.5
# 2  2021-03-31                         98.9  51.1          0.5
# 3  2021-04-30                         99.6  51.8          0.5
# 4  2021-05-31                        100.3  52.4          0.5
#
#    exports_usd_billion  imports_usd_billion  cpi_yoy  unemployment_rate
# 0                 44.7                 42.1      0.6                4.1
# 1                 45.3                 42.7      0.8                4.0
# 2                 46.9                 44.2      1.1                3.9
# 3                 48.2                 45.1      1.4                3.8
# 4                 49.0                 46.3      1.7                3.7

# %%
data_set.dtypes
# Out:
# date                               str
# industrial_production_index    float64
# pmi                            float64
# policy_rate                    float64
# exports_usd_billion            float64
# imports_usd_billion            float64
# cpi_yoy                        float64
# unemployment_rate              float64
# dtype: object

# %%
data_set.date = pd.to_datetime(data_set.date)  # 다시 저장해야함!

# %%
data_set.dtypes
# Out:
# date                           datetime64[us]
# industrial_production_index           float64
# pmi                                   float64
# policy_rate                           float64
# exports_usd_billion                   float64
# imports_usd_billion                   float64
# cpi_yoy                               float64
# unemployment_rate                     float64
# dtype: object

# %%
data_set = data_set.sort_values(by='date', ascending=True) # 다시 저장해야함!

# %%
data_set.date.is_monotonic_increasing
# Out:
# True
